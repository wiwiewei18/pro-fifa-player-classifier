# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Importing Transformed Dataset

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import sys
import os
sys.path.append(os.path.abspath('../../..'))
from utils import pandas_column_utils
from utils import missing_value_utils
from utils import outliers_utils
from utils import array_utils

url = '../../../datasets/preprocessed/transformed.csv'
transformed_fifa_df = pd.read_csv(url, low_memory=False)
cleaned_fifa_df = transformed_fifa_df

# %% [markdown]
# ## Removing Duplicate Data

# %% [markdown]
# ### Checking Duplicate Data

# %%
cleaned_fifa_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Handling Outlier Data

# %% [markdown]
# ### Checking Outlier Data

# %%
parseable_columns = [col for col in cleaned_fifa_df.columns if pandas_column_utils.parseable_to_int(cleaned_fifa_df[col])]

print(parseable_columns)
# Out:
# ['ID', 'Age', 'Overall', 'Potential', 'Value (€)', 'Wage (€)', 'Special', 'International Reputation', 'Weak Foot', 'Skill Moves', 'Joined', 'Contract Valid Until', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Dribbling', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Acceleration', 'Sprint Speed', 'Reactions', 'Shot Power', 'Stamina', 'Strength', 'Long Shots', 'Aggression', 'Penalties', 'Standing Tackle', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Best Overall Rating', 'Encoded Preferred Foot', 'Encoded Best Position']

# %% [markdown]
# ### Handling Outlier Data

# %%
# TODO: Remove, impute, or cap outliers (try to find out most effective way)
to_cap_columns = [
    'Age',
    'Potential',
    'Value (€)',
    'Wage (€)',
    'Special',
    'International Reputation',
    'Weak Foot',
    'Skill Moves',
    'Crossing',
    'Finishing',
    'Heading Accuracy',
    'Short Passing',
    'Dribbling',
    'FK Accuracy',
    'Long Passing',
    'Ball Control',
    'Acceleration',
    'Sprint Speed',
    'Reactions',
    'Shot Power',
    'Stamina',
    'Strength',
    'Long Shots',
    'Aggression',
    'Penalties',
    'Standing Tackle',
    'GK Diving',
    'GK Handling',
    'GK Kicking',
    'GK Positioning',
    'GK Reflexes',
    'Best Overall Rating',
]

for column_name in to_cap_columns:
    cleaned_fifa_df[column_name] = outliers_utils.standard_deviation_capping(cleaned_fifa_df, column_name)

cleaned_fifa_df.head(2)
# Out:
#        ID           Name   Age  \
# 0  176580      L. Suárez  33.0
# 1  192985   K. De Bruyne  29.0
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.com/players/176/580/20_60.png     Uruguay
# 1  https://cdn.sofifa.com/players/192/985/20_60.png     Belgium
#
#                                   Flag  Overall  Potential             Club  \
# 0  https://cdn.sofifa.com/flags/uy.png       87  87.000000  Atlético Madrid
# 1  https://cdn.sofifa.com/flags/be.png       91  89.768582  Manchester City
#
#                                        Club Logo     Value (€)      Wage (€)  \
# 0  https://cdn.sofifa.com/teams/240/light_30.png  1.869589e+07  73807.945008
# 1   https://cdn.sofifa.com/teams/10/light_30.png  1.869589e+07  73807.945008
#
#    Special Preferred Foot  International Reputation  Weak Foot  Skill Moves  \
# 0   2316.0          Right                  2.514853        4.0          3.0
# 1   2304.0          Right                  2.514853        5.0          4.0
#
#       Work Rate             Body Type Real Face Position  Jersey Number  \
# 0  High/ Medium  PLAYER_BODY_TYPE_374       Yes       RS            9.0
# 1    High/ High  PLAYER_BODY_TYPE_321       Yes      RCM           17.0
#
#    Joined Loaned From  Contract Valid Until  Height (m)  Weight (kg)  \
# 0    2020         NaN                  2022      1.8288    86.182480
# 1    2015         NaN                  2023      1.8034    69.853168
#
#    Crossing  Finishing  Heading Accuracy  Short Passing  Volleys  Dribbling  \
# 0      80.0       92.0              84.0           83.0     90.0       84.0
# 1      94.0       82.0              55.0           94.0     82.0       88.0
#
#    Curve  FK Accuracy  Long Passing  Ball Control  Acceleration  Sprint Speed  \
# 0   86.0         82.0          77.0          84.0          72.0          68.0
# 1   85.0         83.0          93.0          92.0          77.0          76.0
#
#    Agility  Reactions  Balance  Shot Power  Jumping  Stamina  Strength  \
# 0     76.0  90.321591     78.0        89.0     69.0     78.0      85.0
# 1     78.0  90.321591     76.0        91.0     63.0     89.0      74.0
#
#    Long Shots  Aggression  Interceptions  Positioning  Vision  Penalties  \
# 0        88.0        87.0           41.0         91.0    84.0       83.0
# 1        91.0        76.0           66.0         88.0    94.0       84.0
#
#    Composure  Marking  Standing Tackle  Sliding Tackle  GK Diving  \
# 0       85.0      NaN             45.0            38.0       27.0
# 1       91.0      NaN             65.0            53.0       15.0
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes Best Position  \
# 0         25.0        31.0            33.0         37.0            ST
# 1         13.0         5.0            10.0         13.0           CAM
#
#    Best Overall Rating  Release Clause (€)  Defensive Awareness  \
# 0            87.000000          64599999.0                 57.0
# 1            88.073376         161000000.0                 68.0
#
#    Encoded Preferred Foot Offensive Work Rate  Encoded Offensive Work Rate  \
# 0                       1                High                          3.0
# 1                       1                High                          3.0
#
#   Defensive Work Rate  Encoded Defensive Work Rate  Encoded Real Face  \
# 0              Medium                          2.0                1.0
# 1                High                          3.0                1.0
#
#    Encoded Position  Encoded Best Position
# 0               3.0                      3
# 1               2.0                      2

# %% [markdown]
# ## Handling Missing Data

# %% [markdown]
# ### Checking Missing Data

# %%
pd.set_option('display.max_rows', None)

missing_value_percentage = missing_value_utils.get_percentage(cleaned_fifa_df)
missing_value_percentage = missing_value_percentage[missing_value_percentage['Percentage'] > 0]
display(missing_value_percentage)

pd.reset_option('display.max_rows')
# Out:
#                              Total  Percentage
# Loaned From                  16186   94.610708
# Marking                      16166   94.493804
# Release Clause (€)            1629    9.521861
# Defensive Awareness            942    5.506196
# Club                           325    1.899696
# Composure                      287    1.677578
# Encoded Defensive Work Rate     59    0.344868
# Encoded Offensive Work Rate     59    0.344868
# Sliding Tackle                  39    0.227964
# Volleys                         39    0.227964
# Balance                         39    0.227964
# Curve                           39    0.227964
# Vision                          39    0.227964
# Jumping                         39    0.227964
# Agility                         39    0.227964
# Real Face                       25    0.146130
# Encoded Real Face               25    0.146130
# Body Type                       25    0.146130
# Jersey Number                   20    0.116904
# Position                        20    0.116904
# Encoded Position                20    0.116904
# Interceptions                    3    0.017536
# Positioning                      3    0.017536

# %%
cleaned_fifa_df[missing_value_percentage.index].head(2)
# Out:
#   Loaned From  Marking  Release Clause (€)  Defensive Awareness  \
# 0         NaN      NaN          64599999.0                 57.0
# 1         NaN      NaN         161000000.0                 68.0
#
#               Club  Composure  Encoded Defensive Work Rate  \
# 0  Atlético Madrid       85.0                          2.0
# 1  Manchester City       91.0                          3.0
#
#    Encoded Offensive Work Rate  Sliding Tackle  Volleys  Balance  Curve  \
# 0                          3.0            38.0     90.0     78.0   86.0
# 1                          3.0            53.0     82.0     76.0   85.0
#
#    Vision  Jumping  Agility Real Face  Encoded Real Face  \
# 0    84.0     69.0     76.0       Yes                1.0
# 1    94.0     63.0     78.0       Yes                1.0
#
#               Body Type  Jersey Number Position  Encoded Position  \
# 0  PLAYER_BODY_TYPE_374            9.0       RS               3.0
# 1  PLAYER_BODY_TYPE_321           17.0      RCM               2.0
#
#    Interceptions  Positioning
# 0           41.0         91.0
# 1           66.0         88.0

# %% [markdown]
# NOTE:
# 1. Removing Column (Missing Value > 50%)
# 2. Filling Column (Missing Value < 50%)

# %% [markdown]
# ### Removing Column (Missing Value > 50%)

# %%
more_than_50_percent_missing_value = missing_value_percentage[missing_value_percentage['Percentage'] > 50]

cleaned_fifa_df = cleaned_fifa_df.drop(more_than_50_percent_missing_value.index, axis=1)

pd.set_option('display.max_rows', None)

missing_value_percentage = missing_value_utils.get_percentage(cleaned_fifa_df)
missing_value_percentage = missing_value_percentage[missing_value_percentage['Percentage'] > 0]
display(missing_value_percentage)

pd.reset_option('display.max_rows')
# Out:
#                              Total  Percentage
# Release Clause (€)            1629    9.521861
# Defensive Awareness            942    5.506196
# Club                           325    1.899696
# Composure                      287    1.677578
# Encoded Defensive Work Rate     59    0.344868
# Encoded Offensive Work Rate     59    0.344868
# Agility                         39    0.227964
# Jumping                         39    0.227964
# Curve                           39    0.227964
# Volleys                         39    0.227964
# Vision                          39    0.227964
# Sliding Tackle                  39    0.227964
# Balance                         39    0.227964
# Body Type                       25    0.146130
# Real Face                       25    0.146130
# Encoded Real Face               25    0.146130
# Encoded Position                20    0.116904
# Position                        20    0.116904
# Jersey Number                   20    0.116904
# Positioning                      3    0.017536
# Interceptions                    3    0.017536

# %% [markdown]
# ### Filling Column (Missing Value < 50%)

# %% [markdown]
# #### Filling Categorical Column

# %%
# -1: unknown
# cleaned_fifa_df = cleaned_fifa_df.fillna({
#     'Joined': 'unknown',
#     'Contract Valid Until': 'unknown',
#     'Club': 'unknown',
#     'Body Type': 'unknown',
#     'Position': 'unknown',
#     'Real Face': 'unknown',
#     'Jersey Number': -1, 
#     'Encoded Defensive Work Rate': -1, 
#     'Encoded Offensive Work Rate': -1, 
#     'Encoded Real Face': -1, 
#     'Encoded Position': -1, 
# })

categorical_cols = [
    'Joined',
    'Contract Valid Until',
    'Club',
    'Body Type',
    'Position',
    'Real Face',
    'Jersey Number',
    'Encoded Defensive Work Rate',
    'Encoded Offensive Work Rate',
    'Encoded Real Face',
    'Encoded Position',
]
cleaned_fifa_df[categorical_cols] = cleaned_fifa_df[categorical_cols].apply(lambda x: x.fillna(x.mode()[0]))

pd.set_option('display.max_rows', None)

missing_value_percentage = missing_value_utils.get_percentage(cleaned_fifa_df)
missing_value_percentage = missing_value_percentage[missing_value_percentage['Percentage'] > 0]
display(missing_value_percentage)

pd.reset_option('display.max_rows')
# Out:
#                      Total  Percentage
# Release Clause (€)    1629    9.521861
# Defensive Awareness    942    5.506196
# Composure              287    1.677578
# Sliding Tackle          39    0.227964
# Balance                 39    0.227964
# Curve                   39    0.227964
# Volleys                 39    0.227964
# Jumping                 39    0.227964
# Vision                  39    0.227964
# Agility                 39    0.227964
# Positioning              3    0.017536
# Interceptions            3    0.017536

# %% [markdown]
# #### Filling Numerical Column

# %%
numerical_columns = [
    'Release Clause (€)',
    'Defensive Awareness',
    'Composure',
    'Sliding Tackle',
    'Balance',
    'Jumping',
    'Volleys',
    'Vision',
    'Curve',
    'Agility',
    'Interceptions',
    'Positioning',
]

contain_outliers_column_names = []

for column_name in numerical_columns:
    if len(outliers_utils.get_outliers(cleaned_fifa_df, column_name)):
        contain_outliers_column_names.append(column_name)
        
no_contain_outliers_column_names = array_utils.subtract(numerical_columns, contain_outliers_column_names)

na_filler = {}

for column_name in contain_outliers_column_names:
    na_filler[column_name] = cleaned_fifa_df[column_name].median()

for column_name in no_contain_outliers_column_names:
    na_filler[column_name] = cleaned_fifa_df[column_name].mean()

cleaned_fifa_df = cleaned_fifa_df.fillna(na_filler)

pd.set_option('display.max_rows', None)

missing_value_percentage = missing_value_utils.get_percentage(cleaned_fifa_df)
missing_value_percentage = missing_value_percentage[missing_value_percentage['Percentage'] > 0]
display(missing_value_percentage)

pd.reset_option('display.max_rows')
# Out:
# Empty DataFrame
# Columns: [Total, Percentage]
# Index: []

# %% [markdown]
# ## Exporting Cleaned Dataset

# %%
cleaned_fifa_df.to_csv('../../../datasets/preprocessed/cleaned.csv', index=False)
cleaned_fifa_df.to_csv('../../../datasets/processed/processed.csv', index=False)
